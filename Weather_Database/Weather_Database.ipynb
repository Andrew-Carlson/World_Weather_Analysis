# %%
# Import dependencies

import pandas as pd

import numpy as np

from citipy import citipy

import random

# %%
# Create a set of 2,000 latitudes and longitudes

lats = np.random.uniform(-90, 90, size = 2000)

longs = np.random.uniform(-180, 180, size = 2000)

lat_lngs = zip(lats, longs)

lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
print(coordinates[0])
# Out:
# (-85.03901091142858, -144.24990357701253)

# %%
# Create a list for holding cities

cities = []

for coordinate in coordinates:
    
    # identify the nearest city for each given coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if city is unique, it will be added to the cities list
    if city not in cities:
        
        cities.append(city)
        
len(cities)
# Out:
# 732

# %%
# Import requests library

import requests

from config import weather_api_key

# assign variable to base url

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 

import time

from datetime import datetime

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters.

record_count = 1

set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try: 
        # Run an API request for each of the cities.
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country" : city_country,
                          "Date": city_date,
                          "Current Description" : city_description})
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | lavrentiya
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | dwarka
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | padang
# Processing Record 9 of Set 1 | port blair
# Processing Record 10 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 1 | canico
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | westport
# Processing Record 14 of Set 1 | henties bay
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | kahului
# Processing Record 19 of Set 1 | grand-santi
# Processing Record 20 of Set 1 | jaszkarajeno
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | morehead
# Processing Record 24 of Set 1 | labuhan
# Processing Record 25 of Set 1 | stolin
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | clyde river
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | montijo
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | pulandian
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | fomboni
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | la libertad
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | ocos
# Processing Record 47 of Set 1 | jackson
# Processing Record 48 of Set 1 | college
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | iguape
# Processing Record 2 of Set 2 | kupang
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | qaqortoq
# Processing Record 6 of Set 2 | marsa matruh
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | polson
# Processing Record 9 of Set 2 | ochakiv
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | yarada
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | oistins
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | lodja
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | balkhash
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | puerto madryn
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | batemans bay
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | beloha
# Processing Record 26 of Set 2 | sandpoint
# Processing Record 27 of Set 2 | faya
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | finschhafen
# Processing Record 31 of Set 2 | rikitea
# Processing Record 32 of Set 2 | lorengau
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | alto paraguai
# Processing Record 37 of Set 2 | kakching
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | ulladulla
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | rio grande
# Processing Record 42 of Set 2 | swellendam
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | xining
# Processing Record 47 of Set 2 | vila franca do campo
# Processing Record 48 of Set 2 | cobija
# Processing Record 49 of Set 2 | caazapa
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | zhezkazgan
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | mayo
# Processing Record 5 of Set 3 | yumen
# Processing Record 6 of Set 3 | mill valley
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | suluova
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | almaznyy
# Processing Record 15 of Set 3 | tautira
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | gombong
# Processing Record 18 of Set 3 | montepuez
# Processing Record 19 of Set 3 | shalakusha
# Processing Record 20 of Set 3 | auki
# Processing Record 21 of Set 3 | varfurile
# Processing Record 22 of Set 3 | dingle
# Processing Record 23 of Set 3 | igrim
# Processing Record 24 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | krasnoselkup
# Processing Record 27 of Set 3 | shambu
# Processing Record 28 of Set 3 | arraial do cabo
# Processing Record 29 of Set 3 | sohag
# Processing Record 30 of Set 3 | ahuimanu
# Processing Record 31 of Set 3 | erdenet
# Processing Record 32 of Set 3 | portland
# Processing Record 33 of Set 3 | palana
# Processing Record 34 of Set 3 | baglan
# Processing Record 35 of Set 3 | touros
# Processing Record 36 of Set 3 | eldorado
# Processing Record 37 of Set 3 | sao raimundo nonato
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | ikongo
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | jamestown
# Processing Record 43 of Set 3 | avera
# Processing Record 44 of Set 3 | bajil
# Processing Record 45 of Set 3 | narsaq
# Processing Record 46 of Set 3 | tura
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 3 | oxford
# Processing Record 1 of Set 4 | sistranda
# Processing Record 2 of Set 4 | jumla
# Processing Record 3 of Set 4 | dhidhdhoo
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | poum
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | pacific grove
# Processing Record 11 of Set 4 | yar-sale
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | okha
# Processing Record 14 of Set 4 | benin
# Processing Record 15 of Set 4 | kyren
# Processing Record 16 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 4 | killeen
# Processing Record 18 of Set 4 | coahuayana
# Processing Record 19 of Set 4 | tahe
# Processing Record 20 of Set 4 | praia
# Processing Record 21 of Set 4 | kununurra
# Processing Record 22 of Set 4 | yuxia
# Processing Record 23 of Set 4 | marsh harbour
# Processing Record 24 of Set 4 | pisco
# Processing Record 25 of Set 4 | chara
# Processing Record 26 of Set 4 | kaoma
# Processing Record 27 of Set 4 | hirara
# Processing Record 28 of Set 4 | namibe
# Processing Record 29 of Set 4 | cravo norte
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | stromness
# Processing Record 32 of Set 4 | vastseliina
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | roald
# Processing Record 35 of Set 4 | saint-pierre
# Processing Record 36 of Set 4 | aldan
# Processing Record 37 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 4 | chapada dos guimaraes
# Processing Record 39 of Set 4 | magistralnyy
# Processing Record 40 of Set 4 | pandan
# Processing Record 41 of Set 4 | hermanus
# Processing Record 42 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 4 | los llanos de aridane
# Processing Record 44 of Set 4 | mount isa
# Processing Record 45 of Set 4 | heide
# Processing Record 46 of Set 4 | olafsvik
# Processing Record 47 of Set 4 | husavik
# Processing Record 48 of Set 4 | houlton
# Processing Record 49 of Set 4 | shubarkuduk
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | ponta delgada
# Processing Record 2 of Set 5 | makat
# Processing Record 3 of Set 5 | qaanaaq
# Processing Record 4 of Set 5 | saint george
# Processing Record 5 of Set 5 | aktas
# Processing Record 6 of Set 5 | pathein
# Processing Record 7 of Set 5 | nuuk
# Processing Record 8 of Set 5 | challapata
# Processing Record 9 of Set 5 | natal
# Processing Record 10 of Set 5 | liwale
# Processing Record 11 of Set 5 | sindand
# City not found. Skipping...
# Processing Record 12 of Set 5 | bukama
# Processing Record 13 of Set 5 | marawi
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | sibolga
# Processing Record 16 of Set 5 | ambilobe
# Processing Record 17 of Set 5 | kibuye
# Processing Record 18 of Set 5 | gasa
# Processing Record 19 of Set 5 | tasiilaq
# Processing Record 20 of Set 5 | waipawa
# Processing Record 21 of Set 5 | sao joao da barra
# Processing Record 22 of Set 5 | margate
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | esik
# Processing Record 25 of Set 5 | havelock
# Processing Record 26 of Set 5 | kidal
# Processing Record 27 of Set 5 | qasigiannguit
# Processing Record 28 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | barra
# Processing Record 31 of Set 5 | vardo
# Processing Record 32 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 5 | haapiti
# Processing Record 34 of Set 5 | cap malheureux
# Processing Record 35 of Set 5 | namatanai
# Processing Record 36 of Set 5 | sembe
# Processing Record 37 of Set 5 | ust-maya
# Processing Record 38 of Set 5 | batagay
# Processing Record 39 of Set 5 | san antonio
# Processing Record 40 of Set 5 | tuxtepec
# Processing Record 41 of Set 5 | ostrovnoy
# Processing Record 42 of Set 5 | port shepstone
# Processing Record 43 of Set 5 | taoudenni
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | mosquera
# Processing Record 46 of Set 5 | atar
# Processing Record 47 of Set 5 | mogadishu
# Processing Record 48 of Set 5 | port hardy
# Processing Record 49 of Set 5 | berlin
# Processing Record 50 of Set 5 | kyabram
# Processing Record 1 of Set 6 | tiksi
# Processing Record 2 of Set 6 | lezajsk
# Processing Record 3 of Set 6 | rio claro
# Processing Record 4 of Set 6 | the valley
# Processing Record 5 of Set 6 | sorland
# Processing Record 6 of Set 6 | north bend
# Processing Record 7 of Set 6 | delijan
# Processing Record 8 of Set 6 | mnogovershinnyy
# Processing Record 9 of Set 6 | hit
# Processing Record 10 of Set 6 | egvekinot
# Processing Record 11 of Set 6 | corinto
# Processing Record 12 of Set 6 | lakes entrance
# Processing Record 13 of Set 6 | cayenne
# Processing Record 14 of Set 6 | severo-kurilsk
# Processing Record 15 of Set 6 | khasan
# Processing Record 16 of Set 6 | wanning
# Processing Record 17 of Set 6 | boueni
# Processing Record 18 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 6 | chicama
# Processing Record 20 of Set 6 | agadir
# Processing Record 21 of Set 6 | ambon
# Processing Record 22 of Set 6 | fortuna
# Processing Record 23 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 6 | woodburn
# Processing Record 25 of Set 6 | hamilton
# Processing Record 26 of Set 6 | chapais
# Processing Record 27 of Set 6 | boende
# Processing Record 28 of Set 6 | kitimat
# Processing Record 29 of Set 6 | poopo
# Processing Record 30 of Set 6 | orje
# Processing Record 31 of Set 6 | hammerfest
# Processing Record 32 of Set 6 | powell river
# Processing Record 33 of Set 6 | sechura
# Processing Record 34 of Set 6 | pangnirtung
# Processing Record 35 of Set 6 | codrington
# Processing Record 36 of Set 6 | igarka
# Processing Record 37 of Set 6 | liverpool
# Processing Record 38 of Set 6 | talnakh
# Processing Record 39 of Set 6 | sillamae
# Processing Record 40 of Set 6 | robertsport
# Processing Record 41 of Set 6 | mayumba
# Processing Record 42 of Set 6 | najran
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | nikki
# Processing Record 45 of Set 6 | helong
# Processing Record 46 of Set 6 | hofn
# Processing Record 47 of Set 6 | ornskoldsvik
# Processing Record 48 of Set 6 | sawtell
# Processing Record 49 of Set 6 | bandarbeyla
# Processing Record 50 of Set 6 | srednekolymsk
# Processing Record 1 of Set 7 | tarpon springs
# Processing Record 2 of Set 7 | farafangana
# Processing Record 3 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 7 | zhuji
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | taltal
# Processing Record 7 of Set 7 | grindavik
# Processing Record 8 of Set 7 | lusaka
# Processing Record 9 of Set 7 | sarangani
# Processing Record 10 of Set 7 | denpasar
# Processing Record 11 of Set 7 | daru
# Processing Record 12 of Set 7 | la macarena
# Processing Record 13 of Set 7 | kaihua
# Processing Record 14 of Set 7 | banjar
# Processing Record 15 of Set 7 | naze
# Processing Record 16 of Set 7 | pop
# Processing Record 17 of Set 7 | road town
# Processing Record 18 of Set 7 | florencia
# Processing Record 19 of Set 7 | badou
# Processing Record 20 of Set 7 | say
# Processing Record 21 of Set 7 | matagami
# Processing Record 22 of Set 7 | paris
# Processing Record 23 of Set 7 | kayerkan
# Processing Record 24 of Set 7 | ponferrada
# Processing Record 25 of Set 7 | walvis bay
# Processing Record 26 of Set 7 | catamarca
# Processing Record 27 of Set 7 | dindori
# Processing Record 28 of Set 7 | paita
# Processing Record 29 of Set 7 | gander
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | vorukh
# Processing Record 32 of Set 7 | paraiso
# Processing Record 33 of Set 7 | tchollire
# Processing Record 34 of Set 7 | kabanjahe
# Processing Record 35 of Set 7 | illapel
# Processing Record 36 of Set 7 | la orilla
# Processing Record 37 of Set 7 | rawson
# Processing Record 38 of Set 7 | nome
# Processing Record 39 of Set 7 | santa fe
# Processing Record 40 of Set 7 | kaeo
# Processing Record 41 of Set 7 | upington
# Processing Record 42 of Set 7 | port-gentil
# Processing Record 43 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 7 | liberia
# Processing Record 45 of Set 7 | marihatag
# Processing Record 46 of Set 7 | bolshaya sosnova
# Processing Record 47 of Set 7 | great yarmouth
# Processing Record 48 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 7 | tavda
# Processing Record 50 of Set 7 | gobabis
# Processing Record 1 of Set 8 | bambous virieux
# Processing Record 2 of Set 8 | mackay
# Processing Record 3 of Set 8 | necochea
# Processing Record 4 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 5 of Set 8 | sobolevo
# Processing Record 6 of Set 8 | nanakuli
# Processing Record 7 of Set 8 | presque isle
# Processing Record 8 of Set 8 | talaya
# Processing Record 9 of Set 8 | puerto rondon
# Processing Record 10 of Set 8 | gornyak
# Processing Record 11 of Set 8 | san luis
# Processing Record 12 of Set 8 | nizhneangarsk
# Processing Record 13 of Set 8 | matara
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | banting
# Processing Record 16 of Set 8 | hithadhoo
# Processing Record 17 of Set 8 | aripuana
# Processing Record 18 of Set 8 | sambava
# Processing Record 19 of Set 8 | galle
# Processing Record 20 of Set 8 | shenjiamen
# Processing Record 21 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 22 of Set 8 | anori
# Processing Record 23 of Set 8 | evensk
# Processing Record 24 of Set 8 | meulaboh
# Processing Record 25 of Set 8 | roseau
# Processing Record 26 of Set 8 | nagato
# Processing Record 27 of Set 8 | aitape
# Processing Record 28 of Set 8 | djenne
# Processing Record 29 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 8 | kyra
# Processing Record 31 of Set 8 | seoul
# Processing Record 32 of Set 8 | aklavik
# Processing Record 33 of Set 8 | flic en flac
# Processing Record 34 of Set 8 | ha giang
# Processing Record 35 of Set 8 | qui nhon
# Processing Record 36 of Set 8 | ghanzi
# Processing Record 37 of Set 8 | iracoubo
# Processing Record 38 of Set 8 | lisburn
# Processing Record 39 of Set 8 | hami
# Processing Record 40 of Set 8 | tukrah
# Processing Record 41 of Set 8 | mehamn
# Processing Record 42 of Set 8 | adrar
# Processing Record 43 of Set 8 | anqing
# Processing Record 44 of Set 8 | palmeiras de goias
# Processing Record 45 of Set 8 | palmer
# Processing Record 46 of Set 8 | ukiah
# Processing Record 47 of Set 8 | nobeoka
# Processing Record 48 of Set 8 | klaksvik
# Processing Record 49 of Set 8 | geraldton
# Processing Record 50 of Set 8 | terme
# Processing Record 1 of Set 9 | shalya
# Processing Record 2 of Set 9 | chalus
# Processing Record 3 of Set 9 | katakwi
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | sapa
# Processing Record 7 of Set 9 | vostok
# Processing Record 8 of Set 9 | karpathos
# Processing Record 9 of Set 9 | veraval
# Processing Record 10 of Set 9 | san rafael
# Processing Record 11 of Set 9 | sai buri
# Processing Record 12 of Set 9 | barsovo
# Processing Record 13 of Set 9 | sangar
# Processing Record 14 of Set 9 | christchurch
# Processing Record 15 of Set 9 | kurchum
# Processing Record 16 of Set 9 | pasni
# Processing Record 17 of Set 9 | neiafu
# Processing Record 18 of Set 9 | guerrero negro
# Processing Record 19 of Set 9 | rio piracicaba
# Processing Record 20 of Set 9 | caconda
# Processing Record 21 of Set 9 | belmonte
# Processing Record 22 of Set 9 | san patricio
# Processing Record 23 of Set 9 | luau
# Processing Record 24 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 9 | saint anthony
# Processing Record 26 of Set 9 | derzhavinsk
# Processing Record 27 of Set 9 | lagoa
# Processing Record 28 of Set 9 | yilan
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | markova
# Processing Record 31 of Set 9 | katangli
# Processing Record 32 of Set 9 | alice town
# Processing Record 33 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 9 | airai
# Processing Record 35 of Set 9 | lebork
# Processing Record 36 of Set 9 | ancud
# Processing Record 37 of Set 9 | iranshahr
# Processing Record 38 of Set 9 | bayshore gardens
# Processing Record 39 of Set 9 | chute-aux-outardes
# Processing Record 40 of Set 9 | san quintin
# Processing Record 41 of Set 9 | antalaha
# Processing Record 42 of Set 9 | deputatskiy
# Processing Record 43 of Set 9 | biak
# Processing Record 44 of Set 9 | musoma
# Processing Record 45 of Set 9 | saint helens
# Processing Record 46 of Set 9 | deep river
# Processing Record 47 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 9 | conakry
# Processing Record 49 of Set 9 | northam
# Processing Record 50 of Set 9 | rafai
# Processing Record 1 of Set 10 | guata
# City not found. Skipping...
# Processing Record 2 of Set 10 | sinnamary
# Processing Record 3 of Set 10 | salalah
# Processing Record 4 of Set 10 | zhangye
# Processing Record 5 of Set 10 | san juan del sur
# Processing Record 6 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | kirkenes
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | goderich
# Processing Record 10 of Set 10 | kenai
# Processing Record 11 of Set 10 | nikita
# Processing Record 12 of Set 10 | dunedin
# Processing Record 13 of Set 10 | tomatlan
# Processing Record 14 of Set 10 | eraniel
# Processing Record 15 of Set 10 | thunder bay
# Processing Record 16 of Set 10 | yei
# Processing Record 17 of Set 10 | kavieng
# Processing Record 18 of Set 10 | hervey bay
# Processing Record 19 of Set 10 | panzhihua
# Processing Record 20 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 21 of Set 10 | havre-saint-pierre
# Processing Record 22 of Set 10 | bougouni
# Processing Record 23 of Set 10 | omboue
# Processing Record 24 of Set 10 | west bay
# Processing Record 25 of Set 10 | kruisfontein
# Processing Record 26 of Set 10 | emerald
# Processing Record 27 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 10 | kunashak
# Processing Record 29 of Set 10 | todos santos
# Processing Record 30 of Set 10 | bayevo
# Processing Record 31 of Set 10 | shingu
# Processing Record 32 of Set 10 | lethem
# Processing Record 33 of Set 10 | coffs harbour
# Processing Record 34 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 10 | slonim
# Processing Record 36 of Set 10 | bowen
# Processing Record 37 of Set 10 | vuktyl
# Processing Record 38 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 10 | arkhipo-osipovka
# Processing Record 40 of Set 10 | herzele
# Processing Record 41 of Set 10 | luanda
# Processing Record 42 of Set 10 | slavyanka
# Processing Record 43 of Set 10 | pitimbu
# Processing Record 44 of Set 10 | ko samui
# Processing Record 45 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 10 | tuatapere
# Processing Record 48 of Set 10 | plouzane
# Processing Record 49 of Set 10 | virginia beach
# Processing Record 50 of Set 10 | yantal
# Processing Record 1 of Set 11 | tabas
# Processing Record 2 of Set 11 | georgiyevka
# Processing Record 3 of Set 11 | vangaindrano
# Processing Record 4 of Set 11 | shimoda
# Processing Record 5 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 11 | terrace
# Processing Record 7 of Set 11 | tsiroanomandidy
# Processing Record 8 of Set 11 | sorong
# Processing Record 9 of Set 11 | conde
# Processing Record 10 of Set 11 | cozumel
# Processing Record 11 of Set 11 | ust-tsilma
# Processing Record 12 of Set 11 | larsnes
# Processing Record 13 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 11 | alexandria
# Processing Record 15 of Set 11 | domoni
# Processing Record 16 of Set 11 | yaan
# Processing Record 17 of Set 11 | mahajanga
# Processing Record 18 of Set 11 | alta floresta
# Processing Record 19 of Set 11 | bure
# Processing Record 20 of Set 11 | bath
# Processing Record 21 of Set 11 | cedar city
# Processing Record 22 of Set 11 | oktyabrskiy
# Processing Record 23 of Set 11 | revda
# Processing Record 24 of Set 11 | itaporanga
# Processing Record 25 of Set 11 | woodstock
# Processing Record 26 of Set 11 | xai-xai
# Processing Record 27 of Set 11 | coos bay
# Processing Record 28 of Set 11 | scarborough
# Processing Record 29 of Set 11 | huarmey
# Processing Record 30 of Set 11 | san juan
# Processing Record 31 of Set 11 | haines junction
# Processing Record 32 of Set 11 | avare
# Processing Record 33 of Set 11 | xuddur
# Processing Record 34 of Set 11 | karasburg
# Processing Record 35 of Set 11 | badaojiang
# City not found. Skipping...
# Processing Record 36 of Set 11 | mocuba
# Processing Record 37 of Set 11 | lumphat
# Processing Record 38 of Set 11 | jalu
# Processing Record 39 of Set 11 | vila velha
# Processing Record 40 of Set 11 | lucea
# Processing Record 41 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 42 of Set 11 | kennett
# Processing Record 43 of Set 11 | luganville
# Processing Record 44 of Set 11 | lesnoy
# Processing Record 45 of Set 11 | mumford
# Processing Record 46 of Set 11 | flinders
# Processing Record 47 of Set 11 | kaabong
# Processing Record 48 of Set 11 | kurilsk
# Processing Record 49 of Set 11 | ahipara
# Processing Record 50 of Set 11 | zelenoborsk
# Processing Record 1 of Set 12 | salinopolis
# Processing Record 2 of Set 12 | riyadh
# Processing Record 3 of Set 12 | sangin
# Processing Record 4 of Set 12 | mujiayingzi
# Processing Record 5 of Set 12 | zyryanka
# Processing Record 6 of Set 12 | los barrios
# Processing Record 7 of Set 12 | yambio
# Processing Record 8 of Set 12 | formosa
# Processing Record 9 of Set 12 | fare
# Processing Record 10 of Set 12 | bam
# Processing Record 11 of Set 12 | bambanglipuro
# Processing Record 12 of Set 12 | tombouctou
# Processing Record 13 of Set 12 | kargasok
# Processing Record 14 of Set 12 | boralday
# Processing Record 15 of Set 12 | inhambane
# Processing Record 16 of Set 12 | alto araguaia
# Processing Record 17 of Set 12 | esna
# Processing Record 18 of Set 12 | sur
# Processing Record 19 of Set 12 | korla
# Processing Record 20 of Set 12 | sao filipe
# Processing Record 21 of Set 12 | haicheng
# Processing Record 22 of Set 12 | riverton
# Processing Record 23 of Set 12 | bima
# Processing Record 24 of Set 12 | alakurtti
# Processing Record 25 of Set 12 | zlatica
# Processing Record 26 of Set 12 | gimli
# Processing Record 27 of Set 12 | puerres
# Processing Record 28 of Set 12 | payakumbuh
# Processing Record 29 of Set 12 | asyut
# Processing Record 30 of Set 12 | vestmannaeyjar
# Processing Record 31 of Set 12 | richards bay
# Processing Record 32 of Set 12 | mallaig
# Processing Record 33 of Set 12 | kavaratti
# Processing Record 34 of Set 12 | shepsi
# Processing Record 35 of Set 12 | dilla
# Processing Record 36 of Set 12 | nishihara
# Processing Record 37 of Set 12 | wenling
# Processing Record 38 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 39 of Set 12 | la asuncion
# Processing Record 40 of Set 12 | saint-joseph
# Processing Record 41 of Set 12 | puerto narino
# Processing Record 42 of Set 12 | kalmunai
# Processing Record 43 of Set 12 | sulphur
# Processing Record 44 of Set 12 | kabalo
# Processing Record 45 of Set 12 | soc trang
# Processing Record 46 of Set 12 | wamba
# Processing Record 47 of Set 12 | sayansk
# Processing Record 48 of Set 12 | slave lake
# Processing Record 49 of Set 12 | sept-iles
# Processing Record 50 of Set 12 | chippewa falls
# Processing Record 1 of Set 13 | rorvik
# Processing Record 2 of Set 13 | lasa
# Processing Record 3 of Set 13 | belyy yar
# Processing Record 4 of Set 13 | ha tinh
# Processing Record 5 of Set 13 | zavetnoye
# Processing Record 6 of Set 13 | leningradskiy
# Processing Record 7 of Set 13 | buala
# Processing Record 8 of Set 13 | coquimbo
# Processing Record 9 of Set 13 | nantucket
# Processing Record 10 of Set 13 | lodwar
# Processing Record 11 of Set 13 | erzin
# Processing Record 12 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 14 of Set 13 | chimbote
# Processing Record 15 of Set 13 | moranbah
# Processing Record 16 of Set 13 | haademeeste
# City not found. Skipping...
# Processing Record 17 of Set 13 | bulanash
# Processing Record 18 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 13 | leirvik
# Processing Record 20 of Set 13 | san vicente
# Processing Record 21 of Set 13 | whitehorse
# Processing Record 22 of Set 13 | ler
# Processing Record 23 of Set 13 | riwaka
# Processing Record 24 of Set 13 | guijalo
# Processing Record 25 of Set 13 | rewa
# Processing Record 26 of Set 13 | olinda
# Processing Record 27 of Set 13 | zvecka
# Processing Record 28 of Set 13 | makakilo city
# Processing Record 29 of Set 13 | baruun-urt
# Processing Record 30 of Set 13 | santa teresa
# Processing Record 31 of Set 13 | yadgir
# Processing Record 32 of Set 13 | dicabisagan
# Processing Record 33 of Set 13 | vytegra
# Processing Record 34 of Set 13 | palora
# Processing Record 35 of Set 13 | elesbao veloso
# Processing Record 36 of Set 13 | davila
# Processing Record 37 of Set 13 | vanimo
# Processing Record 38 of Set 13 | pakhtakoron
# Processing Record 39 of Set 13 | popondetta
# Processing Record 40 of Set 13 | novoorsk
# Processing Record 41 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 42 of Set 13 | elizabeth city
# Processing Record 43 of Set 13 | lubbock
# Processing Record 44 of Set 13 | karratha
# Processing Record 45 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 13 | nouadhibou
# Processing Record 47 of Set 13 | karaton
# Processing Record 48 of Set 13 | santiago del estero
# Processing Record 49 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 50 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 1 of Set 14 | yenagoa
# Processing Record 2 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record 3 of Set 14 | alice springs
# Processing Record 4 of Set 14 | iroquois falls
# Processing Record 5 of Set 14 | crepy-en-valois
# Processing Record 6 of Set 14 | nicoya
# Processing Record 7 of Set 14 | zajas
# Processing Record 8 of Set 14 | port moresby
# Processing Record 9 of Set 14 | shitanjing
# Processing Record 10 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 14 | quepos
# Processing Record 12 of Set 14 | seymchan
# Processing Record 13 of Set 14 | mikhaylovka
# Processing Record 14 of Set 14 | hambantota
# Processing Record 15 of Set 14 | inirida
# Processing Record 16 of Set 14 | parfenyevo
# Processing Record 17 of Set 14 | dongsheng
# Processing Record 18 of Set 14 | bar
# Processing Record 19 of Set 14 | turan
# Processing Record 20 of Set 14 | ormara
# Processing Record 21 of Set 14 | acapulco
# Processing Record 22 of Set 14 | spirovo
# Processing Record 23 of Set 14 | katherine
# Processing Record 24 of Set 14 | laguna
# Processing Record 25 of Set 14 | cockburn town
# Processing Record 26 of Set 14 | tamandare
# Processing Record 27 of Set 14 | salmas
# Processing Record 28 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 14 | voh
# Processing Record 30 of Set 14 | provost
# Processing Record 31 of Set 14 | omis
# Processing Record 32 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 14 | sankt wendel
# Processing Record 34 of Set 14 | chuguyevka
# Processing Record 35 of Set 14 | tromso
# Processing Record 36 of Set 14 | calvinia
# Processing Record 37 of Set 14 | sakakah
# Processing Record 38 of Set 14 | sitka
# Processing Record 39 of Set 14 | beidao
# Processing Record 40 of Set 14 | diego de almagro
# Processing Record 41 of Set 14 | japura
# Processing Record 42 of Set 14 | kamiiso
# Processing Record 43 of Set 14 | miandrivazo
# Processing Record 44 of Set 14 | chifeng
# Processing Record 45 of Set 14 | vestmanna
# Processing Record 46 of Set 14 | venustiano carranza
# Processing Record 47 of Set 14 | uturoa
# Processing Record 48 of Set 14 | athens
# Processing Record 49 of Set 14 | ojinaga
# Processing Record 50 of Set 14 | half moon bay
# Processing Record 1 of Set 15 | ampanihy
# Processing Record 2 of Set 15 | caravelas
# Processing Record 3 of Set 15 | alyangula
# Processing Record 4 of Set 15 | tigil
# Processing Record 5 of Set 15 | lagos
# Processing Record 6 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 15 | guatire
# Processing Record 8 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 15 | turochak
# Processing Record 10 of Set 15 | gorontalo
# Processing Record 11 of Set 15 | moyale
# Processing Record 12 of Set 15 | minudasht
# Processing Record 13 of Set 15 | darhan
# Processing Record 14 of Set 15 | cardedeu
# Processing Record 15 of Set 15 | livingstone
# Processing Record 16 of Set 15 | mackenzie
# Processing Record 17 of Set 15 | skjervoy
# Processing Record 18 of Set 15 | issia
# Processing Record 19 of Set 15 | myitkyina
# Processing Record 20 of Set 15 | linqiong
# Processing Record 21 of Set 15 | shache
# Processing Record 22 of Set 15 | goure
# Processing Record 23 of Set 15 | santa maria
# Processing Record 24 of Set 15 | ginir
# Processing Record 25 of Set 15 | arequipa
# Processing Record 26 of Set 15 | labytnangi
# Processing Record 27 of Set 15 | florence
# Processing Record 28 of Set 15 | wucheng
# Processing Record 29 of Set 15 | acajutla
# Processing Record 30 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 31 of Set 15 | sukpak
# Processing Record 32 of Set 15 | muros
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create dataframe with city_data

city_data_df = pd.DataFrame(city_data)

# Reorder dataframe 

new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

city_data_df = city_data_df[new_column_order]

city_data_df

# Create outpuit file

output_data_file = "WeatherPy_Database.csv"

# export city_data dataframe to csv file

city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %%
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0     Mataura      NZ  2022-07-28 19:47:38 -46.1927  168.8643     47.48
# 1     Ushuaia      AR  2022-07-28 19:47:39 -54.8000  -68.3000     46.06
# 2  Lavrentiya      RU  2022-07-28 19:46:52  65.5833 -171.0000     43.70
# 3    Khatanga      RU  2022-07-28 19:44:24  71.9667  102.5000     59.31
# 4      Dwarka      IN  2022-07-28 19:47:39  22.2394   68.9678     81.54
# 5   Esperance      AU  2022-07-28 19:47:40 -33.8667  121.9000     57.16
# 6      Atuona      PF  2022-07-28 19:46:33  -9.8000 -139.0333     76.73
# 7      Padang      ID  2022-07-28 19:42:55  -0.9492  100.3543     78.31
# 8  Port Blair      IN  2022-07-28 19:47:40  11.6667   92.7500     82.44
# 9      Canico      PT  2022-07-28 19:47:41  32.6333  -16.8500     75.70
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        98         100        3.13     overcast clouds
# 1        53          75       17.27       broken clouds
# 2        88         100        4.94     overcast clouds
# 3        69          53        5.06       broken clouds
# 4        78          88       11.97     overcast clouds
# 5        81           1       12.37           clear sky
# 6        77          28       24.96          light rain
# 7        85         100        4.16          light rain
# 8        83          40        3.44                mist
# 9        78          20       11.50          few clouds
